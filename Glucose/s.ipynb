# %%
import pandas as pd

# %%
df = pd.read_csv("CGMData.csv")
df.head()
# Out:
# /tmp/ipykernel_243805/1796423919.py:1: DtypeWarning: Columns (32) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("CGMData.csv")
#    Index       Date      Time  New Device Time  BG Reading (mg/dL)  \
# 0  20355  2/12/2018  13:22:27              NaN                 NaN
# 1  20356  2/12/2018  13:17:27              NaN                 NaN
# 2  20357  2/12/2018  13:12:27              NaN                 NaN
# 3  20358  2/12/2018  13:07:27              NaN                 NaN
# 4  20359  2/12/2018  13:02:27              NaN                 NaN
#
#    Linked BG Meter ID  Basal Rate (U/h)  Temp Basal Amount  Temp Basal Type  \
# 0                 NaN               NaN                NaN              NaN
# 1                 NaN               NaN                NaN              NaN
# 2                 NaN               NaN                NaN              NaN
# 3                 NaN               NaN                NaN              NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55343 entries, 0 to 55342
# Data columns (total 47 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Index                                55343 non-null  int64
#  1   Date                                 55343 non-null  object
#  2   Time                                 55343 non-null  object
#  3   New Device Time                      0 non-null      float64
#  4   BG Reading (mg/dL)                   0 non-null      float64
#  5   Linked BG Meter ID                   0 non-null      float64
#  6   Basal Rate (U/h)                     0 non-null      float64
#  7   Temp Basal Amount                    0 non-null      float64
#  8   Temp Basal Type                      0 non-null      float64
#  9   Temp Basal Duration (h:mm:ss)        0 non-null      float64
#  10  Bolus Type                           0 non-null      float64
# ...

# %%
df1 = pd.read_csv("InsulinData.csv")
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41435 entries, 0 to 41434
# Data columns (total 47 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Index                                41435 non-null  int64
#  1   Date                                 41435 non-null  object
#  2   Time                                 41435 non-null  object
#  3   New Device Time                      8 non-null      object
#  4   BG Reading (mg/dL)                   3737 non-null   float64
#  5   Linked BG Meter ID                   0 non-null      float64
#  6   Basal Rate (U/h)                     2022 non-null   float64
#  7   Temp Basal Amount                    0 non-null      float64
#  8   Temp Basal Type                      0 non-null      float64
#  9   Temp Basal Duration (h:mm:ss)        0 non-null      float64
#  10  Bolus Type                           29501 non-null  object
# ...

# %%
df1.head()
# Out:
#    Index       Date      Time New Device Time  BG Reading (mg/dL)  \
# 0      0  2/12/2018  13:20:53             NaN                 NaN
# 1      1  2/12/2018  13:20:48             NaN                 NaN
# 2      2  2/12/2018  13:18:48             NaN                 NaN
# 3      3  2/12/2018  13:18:48             NaN                 NaN
# 4      4  2/12/2018  13:12:33             NaN                 NaN
#
#    Linked BG Meter ID  Basal Rate (U/h)  Temp Basal Amount  Temp Basal Type  \
# 0                 NaN               NaN                NaN              NaN
# 1                 NaN               NaN                NaN              NaN
# 2                 NaN               0.0                NaN              NaN
# 3                 NaN               NaN                NaN              NaN
# 4                 NaN               NaN                NaN              NaN
#
#    Temp Basal Duration (h:mm:ss)  ... Scroll Step Size  \
# ...

# %%
df[['Date', 'Time', 'New Device Time']].head()
# Out:
#         Date      Time  New Device Time
# 0  2/12/2018  13:22:27              NaN
# 1  2/12/2018  13:17:27              NaN
# 2  2/12/2018  13:12:27              NaN
# 3  2/12/2018  13:07:27              NaN
# 4  2/12/2018  13:02:27              NaN

# %%
for col in df1.columns:
    if df1[col].dtype == object or df1[col].dtype == 'O':
        # Look for the string in that column
        if df1[col].str.contains("AUTO MODE ACTIVE PLGM OFF", na=False).any():
            print(f"Found auto-mode text in column: {col}")
# Out:
# Found auto-mode text in column: Alarm
