# %%
import pandas as pd
insulin_df = pd.read_csv("InsulinData.csv")
insulin_df.head()
# Out:
# /tmp/ipykernel_12189/2310249815.py:2: DtypeWarning: Columns (13,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   insulin_df = pd.read_csv("InsulinData.csv")
#    Index       Date      Time New Device Time  BG Reading (mg/dL)  \
# 0      0  2/12/2018  13:20:53             NaN                 NaN
# 1      1  2/12/2018  13:20:48             NaN                 NaN
# 2      2  2/12/2018  13:18:48             NaN                 NaN
# 3      3  2/12/2018  13:18:48             NaN                 NaN
# 4      4  2/12/2018  13:12:33             NaN                 NaN
#
#    Linked BG Meter ID  Basal Rate (U/h)  Temp Basal Amount  Temp Basal Type  \
# 0                 NaN               NaN                NaN              NaN
# 1                 NaN               NaN                NaN              NaN
# 2                 NaN               0.0                NaN              NaN
# 3                 NaN               NaN                NaN              NaN
# ...

# %%
insulin_df2 = pd.read_csv("Insulin_patient2.csv")
insulin_df2.head()
# Out:
# /tmp/ipykernel_12189/1483417061.py:1: DtypeWarning: Columns (9,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   insulin_df2 = pd.read_csv("Insulin_patient2.csv")
#    Unnamed: 0  Index        Date      Time New Device Time  \
# 0           0   6564  2018-03-07  11:36:15             NaN
# 1           1   6565  2018-03-07  11:35:56             NaN
# 2           2   6566  2018-03-07  11:33:19             NaN
# 3           3   6567  2018-03-07  11:33:19             NaN
# 4           4   6568  2018-03-07  11:31:04             NaN
#
#    BG Reading (mg/dL)  Linked BG Meter ID  Basal Rate (U/h)  \
# 0                 NaN                 NaN               NaN
# 1                 NaN                 NaN               NaN
# 2                 NaN                 NaN               0.0
# 3                 NaN                 NaN               NaN
# 4                 NaN                 NaN               NaN
#
# ...

# %%
cgm_df = pd.read_csv("CGMData.csv")
cgm_df.head()
# Out:
# /tmp/ipykernel_12189/4081494645.py:1: DtypeWarning: Columns (32) have mixed types. Specify dtype option on import or set low_memory=False.
#   cgm_df = pd.read_csv("CGMData.csv")
#    Index       Date      Time  New Device Time  BG Reading (mg/dL)  \
# 0  20355  2/12/2018  13:22:27              NaN                 NaN
# 1  20356  2/12/2018  13:17:27              NaN                 NaN
# 2  20357  2/12/2018  13:12:27              NaN                 NaN
# 3  20358  2/12/2018  13:07:27              NaN                 NaN
# 4  20359  2/12/2018  13:02:27              NaN                 NaN
#
#    Linked BG Meter ID  Basal Rate (U/h)  Temp Basal Amount  Temp Basal Type  \
# 0                 NaN               NaN                NaN              NaN
# 1                 NaN               NaN                NaN              NaN
# 2                 NaN               NaN                NaN              NaN
# 3                 NaN               NaN                NaN              NaN
# ...

# %%
cgm_df2 = pd.read_csv("CGM_patient2.csv")
cgm_df2.head()
# Out:
#    Unnamed: 0  Index        Date      Time  New Device Time  \
# 0           0  21012  2018-03-07  11:30:48              NaN
# 1           1  21013  2018-03-07  11:25:48              NaN
# 2           2  21014  2018-03-07  11:20:48              NaN
# 3           3  21015  2018-03-07  11:15:48              NaN
# 4           4  21016  2018-03-07  11:10:48              NaN
#
#    BG Reading (mg/dL)  Linked BG Meter ID  Basal Rate (U/h)  \
# 0                 NaN                 NaN               NaN
# 1                 NaN                 NaN               NaN
# 2                 NaN                 NaN               NaN
# 3                 NaN                 NaN               NaN
# 4                 NaN                 NaN               NaN
#
#    Temp Basal Amount  Temp Basal Type  ...  Scroll Step Size  \
# 0                NaN              NaN  ...               NaN
# 1                NaN              NaN  ...               NaN
# ...

# %%
insulin_df.columns
# Out:
# Index(['Index', 'Date', 'Time', 'New Device Time', 'BG Reading (mg/dL)',
#        'Linked BG Meter ID', 'Basal Rate (U/h)', 'Temp Basal Amount',
#        'Temp Basal Type', 'Temp Basal Duration (h:mm:ss)', 'Bolus Type',
#        'Bolus Volume Selected (U)', 'Bolus Volume Delivered (U)',
#        'Bolus Duration (h:mm:ss)', 'Prime Type', 'Prime Volume Delivered (U)',
#        'Alarm', 'Suspend', 'Rewind', 'BWZ Estimate (U)',
#        'BWZ Target High BG (mg/dL)', 'BWZ Target Low BG (mg/dL)',
#        'BWZ Carb Ratio (g/U)', 'BWZ Insulin Sensitivity (mg/dL/U)',
#        'BWZ Carb Input (grams)', 'BWZ BG Input (mg/dL)',
#        'BWZ Correction Estimate (U)', 'BWZ Food Estimate (U)',
#        'BWZ Active Insulin (U)', 'Sensor Calibration BG (mg/dL)',
#        'Sensor Glucose (mg/dL)', 'ISIG Value', 'Event Marker', 'Bolus Number',
#        'Bolus Cancellation Reason', 'BWZ Unabsorbed Insulin Total (U)',
#        'Final Bolus Estimate', 'Scroll Step Size', 'Insulin Action Curve Time',
# ...

# %%
cgm_df.columns
# Out:
# Index(['Index', 'Date', 'Time', 'New Device Time', 'BG Reading (mg/dL)',
#        'Linked BG Meter ID', 'Basal Rate (U/h)', 'Temp Basal Amount',
#        'Temp Basal Type', 'Temp Basal Duration (h:mm:ss)', 'Bolus Type',
#        'Bolus Volume Selected (U)', 'Bolus Volume Delivered (U)',
#        'Bolus Duration (h:mm:ss)', 'Prime Type', 'Prime Volume Delivered (U)',
#        'Alarm', 'Suspend', 'Rewind', 'BWZ Estimate (U)',
#        'BWZ Target High BG (mg/dL)', 'BWZ Target Low BG (mg/dL)',
#        'BWZ Carb Ratio (g/U)', 'BWZ Insulin Sensitivity (mg/dL/U)',
#        'BWZ Carb Input (grams)', 'BWZ BG Input (mg/dL)',
#        'BWZ Correction Estimate (U)', 'BWZ Food Estimate (U)',
#        'BWZ Active Insulin (U)', 'Sensor Calibration BG (mg/dL)',
#        'Sensor Glucose (mg/dL)', 'ISIG Value', 'Event Marker', 'Bolus Number',
#        'Bolus Cancellation Reason', 'BWZ Unabsorbed Insulin Total (U)',
#        'Final Bolus Estimate', 'Scroll Step Size', 'Insulin Action Curve Time',
# ...
